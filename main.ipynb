# %%
from A_Imgs_to_Datasets import Crear_Datasets
from B_Crear_Recortes import Ejecutar_Crear_Recortes
from C_Autoencoder import Ejecutar_AutoEncoder
from D_Clasificadores import Entrenar_Clasificadores

# %%
Crear_Datasets()
# Out:
# cargando imagenes: 121it [00:00, 59608.97it/s]
# cargando imagenes: 121it [00:00, 39048.30it/s]
# cargando imagenes: 121it [00:00, 73884.23it/s]
# cargando imagenes: 121it [00:00, 72928.69it/s]
# ...
# Copiando test: 100%|██████████████████████████████| 24/24 [01:18<00:00,  3.27s/it]

# %%
Ejecutar_Crear_Recortes(tiny_set = False)
# Out:
# ...
# Imagen: 22B33749.A.1.1_area_6:  51%|██████▋      | 66/129 [00:24<00:23,  2.71it/s]
# Error en recorte (44, 66) de 22B33749.A.1.1_area_6: Not a JPEG file: starts with 0xd1 0x5d
# ...
# Imagen: 23B00278.A.3.1_area_3: 100%|████████████| 115/115 [01:18<00:00,  1.46it/s]

# %%
Ejecutar_AutoEncoder(train_and_extract=True)
# Out:
# GPU 0: Memoria libre: 47.19 GB de 47.54 GB totales
# GPU 1: Memoria libre: 46.86 GB de 47.54 GB totales
# GPU 2: Memoria libre: 10.73 GB de 10.91 GB totales
# GPU 3: Memoria libre: 10.72 GB de 10.91 GB totales
# Usando dispositivo: cuda:0
# Probando configuración: {'num_kernels': 4, 'depth': 6, 'learning_rate': 0.001}
# Epoch 1/4: 100%|██████████████████████████████| 1122/1122 [13:33<00:00,  1.38it/s]
# Epoch 1/4, Training Loss: 0.9880, Validation Loss: 0.9880
# Epoch 2/4: 100%|██████████████████████████████| 1122/1122 [13:31<00:00,  1.38it/s]
# Epoch 2/4, Training Loss: 0.4330, Validation Loss: 0.2298
# Epoch 3/4: 100%|██████████████████████████████| 1122/1122 [13:34<00:00,  1.38it/s]
# Epoch 3/4, Training Loss: 0.0961, Validation Loss: 0.0890
# Epoch 4/4:  54%|████████████████▋              | 606/1122 [07:17<06:03,  1.42it/s]

# %%
Entrenar_Clasificadores()
