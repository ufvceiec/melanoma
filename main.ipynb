# %%
dataset = False
autoencoder = False
vectores = False
mantener_perfectos = True
show_PCA = False
balancear_datos = True
vector_deseado = "mean"

# %%
from src.AA_Imgs_to_Datasets import Crear_Datasets
from src.CB_Train_Autoencoder import Ejecutar_AutoEncoder
from src.CE_Crear_Vectores import Crear_Vectores
from src.DA_Clasificadores import Ejecutar_Clasificadores

# %%
if dataset:
    Crear_Datasets()

# %%
if autoencoder:
    Ejecutar_AutoEncoder(train_and_extract=False, mostrar_img=False)

# %%
if vectores:
    Crear_Vectores(skip=0)

# %%
Ejecutar_Clasificadores(mantener_perfectos=mantener_perfectos, 
                        show_PCA=show_PCA, 
                        balancear_datos=balancear_datos, 
                        vector_deseado =vector_deseado)
# Out:
# Cargando imágenes: 1271it [00:00, 86355.12it/s]
# Nevus : 1029
# Melanoma : 212
# Cargando vectores: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 1267/1267 [06:20<00:00,  3.33it/s]
# ✅ Archivos válidos procesados: 1240
# 📊 Vector: maximum → Clase 0: 212 | Clase 1: 212
# 📊 Vector: minimum → Clase 0: 212 | Clase 1: 212
# 📊 Vector: mean → Clase 0: 212 | Clase 1: 212
# 📊 Vector: sum → Clase 0: 212 | Clase 1: 212
# 📊 Vector: median → Clase 0: 212 | Clase 1: 212
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Procesando modelo: KNN, Vector: mean
#    ✅ Test solo con imágenes rotación 0: 98 muestras
#    🧪 Train con el resto: 326 muestras
# 📁 Archivos de entrenamiento guardados en: ./nombres_archivos_train_test/rain_files.csv
# 📁 Archivos de prueba guardados en: ./nombres_archivos_train_test/test_files.csv
# Usando dispositivo: cpu
# ...
